# %%
# import pacakage
# !pip install torch
# !pip install torchvision

# %% [markdown]
# ## **CIFAR 10 데이터셋을 이용하여 신경망 모델 훈련시키고 평가하기 (Pytorch)**

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch as th
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# %% [markdown]
# #### **데이터셋 불러오기 및 전처리**

# %%
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))])
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# #### **데이터셋 크기 확인하기**

# %%
train_dataset_size =
test_dataset_size =
print(f"train data 개수: {train_dataset_size}")
print(f"test data 개수: {test_dataset_size}")
# Out:
# train data 개수: 50000
# test data 개수: 10000

# %% [markdown]
# #### **데이터 shape 확인하기**

# %%
# Hint: 불러온 데이터셋에서 인덱스를 활용
X_shape =
print(f"X_shape: {X_shape}")
# Out:
# X_shape: torch.Size([3, 32, 32])

# %% [markdown]
# #### **신경망 모델 만들기 (Pytorch 사용)**
# - 은닉층
#   - 입력 데이터를 일자로 펼쳐주는 Flatten Layer
#   - output 크기가 200인 Dense Layer 2개 연결 (활성화 함수는 ReLU)
# - 출력층
#   - output 크기가 10인 Dense Layer

# %%
class MyModel(nn.Module):

  def __init__(self):
    super(MyModel, self).__init__()
    self.flatten_layer = 
    self.dense1_layer = 
    self.dense2_layer = 
    self.output_layer = 

  def forward(self, x):

model = MyModel()
model
# Out:
# MyModel(
#   (flatten_layer): Flatten(start_dim=1, end_dim=-1)
#   (dense1_layer): Sequential(
#     (0): Linear(in_features=3072, out_features=200, bias=True)
#     (1): ReLU()
#   )
#   (dense2_layer): Sequential(
#     (0): Linear(in_features=200, out_features=200, bias=True)
#     (1): ReLU()
#   )
#   (output_layer): Sequential(
#     (0): Linear(in_features=200, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# #### **신경망 모델 훈련시키기**
#
# - 손실 함수 (Loss function): Cross Entropy
# - 옵티마이저 (Optimizer): Adam
# - 학습률 (Learning rate): 0.005
# - 배치 크기 (Batch size): 128
# - Epoch: 50

# %%
# 손실함수, 옵티마이저 설정
loss =
optimizer =

# DataLoader 생성
train_dataloader =

# 모델 훈련 (각 epoch마다 train loss값 출력하고 리스트에 저장하기)
epochs =
# Out:
# Epoch 1/20   train_loss: 1.7213
#
# Epoch 2/20   train_loss: 1.5611
#
# Epoch 3/20   train_loss: 1.4898
#
# Epoch 4/20   train_loss: 1.4265
#
# Epoch 5/20   train_loss: 1.3811
#
# Epoch 6/20   train_loss: 1.3384
#
# Epoch 7/20   train_loss: 1.3042
#
# Epoch 8/20   train_loss: 1.2647
#
# Epoch 9/20   train_loss: 1.2403
#
# Epoch 10/20   train_loss: 1.2089
#
# Epoch 11/20   train_loss: 1.1792
#
# Epoch 12/20   train_loss: 1.1417
#
# Epoch 13/20   train_loss: 1.1251
#
# Epoch 14/20   train_loss: 1.1033
#
# Epoch 15/20   train_loss: 1.0725
#
# Epoch 16/20   train_loss: 1.0454
#
# Epoch 17/20   train_loss: 1.034
#
# Epoch 18/20   train_loss: 1.0163
#
# Epoch 19/20   train_loss: 0.9867
#
# Epoch 20/20   train_loss: 0.9697

# %% [markdown]
# #### **train loss 그래프 그리기**

# %%
plt.show()

# %% [markdown]
# ### **신경망 모델 만들기 (Tensorflow 사용)**
# - 은닉층
#   - 입력 데이터를 일자로 펼쳐주는 Flatten Layer
#   - output 크기가 200인 Dense Layer 2개 연결 (활성화 함수는 Tanh)
# - 출력층
#   - output 크기가 10인 Dense Layer

# %%
# !pip install tensorflow

# %%
# Tensorflow용 데이터셋 불러오기
from tensorflow.keras.datasets import cifar10
(x_train,y_train),(x_test, y_test) = cifar10.load_data()

# %%
#필요 모듈 import
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# 모델 구축
class TFlowModel(tf.keras.Model):
    def __init__(self):
        super(TFlowModel, self).__init__()
        self.flatten_layer = 
        self.dense1_layer = 
        self.dense2_layer = 
        self.output_layer = 

    def call(self, x):
        x = self.flatten_layer(x)
        x = self.dense1_layer(x)
        x = self.dense2_layer(x)
        x = self.output_layer(x)
        return x

# Create an instance of the model
TFmodel = TFlowModel()

# %% [markdown]
# #### **신경망 모델 훈련시키기**
#
# - 손실 함수 (Loss function): Cross Entropy
# - 옵티마이저 (Optimizer): Adam
# - 학습률 (Learning rate): 0.005
# - 모델 성능 지표: Accuracy
# - 배치 크기 (Batch size): 128
# - Epoch: 50

# %%
loss = 
optimizer = 
TFmodel.compile()
history =
# Out:
# Epoch 1/20
# 391/391 [==============================] - 4s 8ms/step - loss: 2.3681 - accuracy: 0.1008 - val_loss: 2.3614 - val_accuracy: 0.1000
# Epoch 2/20
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3465 - accuracy: 0.0998 - val_loss: 2.3557 - val_accuracy: 0.1000
# Epoch 3/20
# 391/391 [==============================] - 3s 7ms/step - loss: 2.3498 - accuracy: 0.1002 - val_loss: 2.3432 - val_accuracy: 0.1000
# Epoch 4/20
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3509 - accuracy: 0.0980 - val_loss: 2.3311 - val_accuracy: 0.1000
# Epoch 5/20
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3459 - accuracy: 0.0983 - val_loss: 2.3243 - val_accuracy: 0.1000
# Epoch 6/20
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3571 - accuracy: 0.0950 - val_loss: 2.3324 - val_accuracy: 0.1000
# Epoch 7/20
# ...

# %% [markdown]
# #### **test dataset을 이용하여 모델 평가하기**

# %%
# 모델 평가 (테스트 데이터 이용)
_ , accuracy = 
print(f"Accuracy: {accuracy}")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 2.3724 - accuracy: 0.1000
# Accuracy: 0.10000000149011612

# %% [markdown]
# #### **훈련된 모델로 예측하기 (Pytorch)**

# %%
classes = {0:"airplane", 1:"automobile", 2:"bird", 3:"cat", 4:"deer", 5:"dog", 6:"frog", 7:"horse", 8:"ship", 9:"truck"}

# %%
data = test_dataset[1][0].unsqueeze(0)

pred_label =
print(f"Predicted label: {pred_label}")
print(f"True label: {classes[test_dataset[1][1]]}\n")

plt.imshow(((data.squeeze(0)+1)/2).permute(1,2,0).numpy())
plt.show()
# Out:
# Predicted label: ship
# True label: ship

# %% [markdown]
# #### **(Tensorflow)**

# %%
y_pred = 
print(f"Predicted label: {classes[int(np.argmax(y_pred, axis=1))]}")
print(f"True label: {classes[int(y_test[:1])]}\n")

plt.imshow(x_test[0])
plt.show()
# Out:
# 1/1 [==============================] - 0s 56ms/step
# Predicted label: bird
# True label: cat
